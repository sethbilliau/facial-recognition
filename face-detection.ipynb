# %%
# check opencv version
import cv2
# print version number
print(cv2.__version__)
# Out:
# 4.5.3

# %%
import mtcnn
# print version
print(mtcnn.__version__)
# Out:
# 2021-10-01 22:08:34.031169: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-10-01 22:08:34.036330: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 0.1.0

# %%
# face detection with mtcnn on a photograph
import matplotlib.pyplot as plt
from mtcnn.mtcnn import MTCNN
# load image from file
filename = 'data/images-custom/sethjpg/seth6.JPG'
pixels = plt.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
for face in faces:
    print(face)
# Out:
# 2021-10-01 22:11:14.419859: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-10-01 22:11:14.419964: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-10-01 22:11:14.420006: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (14525f8d3791): /proc/driver/nvidia/version does not exist
# 2021-10-01 22:11:14.420341: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-01 22:11:15.422230: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 52707600 exceeds 10% of free system memory.
# 2021-10-01 22:11:15.516585: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-10-01 22:11:15.788209: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 52707600 exceeds 10% of free system memory.
# 2021-10-01 22:11:15.812798: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 175353360 exceeds 10% of free system memory.
# 2021-10-01 22:11:16.020964: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 175353360 exceeds 10% of free system memory.
# 2021-10-01 22:11:16.021786: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 175353360 exceeds 10% of free system memory.
# {'box': [1977, 1140, 445, 551], 'confidence': 0.9999754428863525, 'keypoints': {'left_eye': (2099, 1352), 'right_eye': (2301, 1339), 'nose': (2212, 1457), 'mouth_left': (2112, 1549), 'mouth_right': (2315, 1534)}}

# %%
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from mtcnn.mtcnn import MTCNN
 
# draw an image with detected objects
def draw_image_with_boxes(filename, result_list):
    # load the image
    data = pyplot.imread(filename)
    # plot the image
    pyplot.imshow(data)
    # get the context for drawing boxes
    ax = pyplot.gca()
    # plot each box
    for result in result_list:
        # get coordinates
        x, y, width, height = result['box']
        # create the shape
        rect = Rectangle((x, y), width, height, fill=False, color='red')
        # draw the box
        ax.add_patch(rect)
    # show the plot
    pyplot.show()


filename = 'data/images-custom/sethjpg/seth6.JPG'
# load image from file
pixels = pyplot.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_image_with_boxes(filename, faces)
# Out:
# WARNING:tensorflow:5 out of the last 60 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fda04f5c1f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from matplotlib.patches import Circle
from mtcnn.mtcnn import MTCNN
 
# draw each face separately
def draw_faces(filename, result_list):
    # load the image
    data = pyplot.imread(filename)
    # plot each face as a subplot
    for i in range(len(result_list)):
        # get coordinates
        x1, y1, width, height = result_list[i]['box']
        x2, y2 = x1 + width, y1 + height
        # define subplot
        pyplot.subplot(1, len(result_list), i+1)
        pyplot.axis('off')
        # plot face
        pyplot.imshow(data[y1:y2, x1:x2])
    # show the plot
    pyplot.show()

filename = 'data/images-custom/sethjpg/seth6.JPG'
# load image from file
pixels = pyplot.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_faces(filename, faces)
# Out:
# WARNING:tensorflow:5 out of the last 60 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fda03dbbca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
